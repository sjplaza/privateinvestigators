# %%
# Dependencies
import pandas as pd
import pprint as pprint
import matplotlib.pyplot as plt
import numpy as np

# %%
# create file path 
hate_crime_csv = "hate_crime.csv"

# %%
# read the csv

hate_crime_df = pd.read_csv(hate_crime_csv, low_memory=False)
hate_crime_df.head()
# Out:
#    INCIDENT_ID  DATA_YEAR        ORI PUB_AGENCY_NAME PUB_AGENCY_UNIT  \
# 0         3015       1991  AR0040200          Rogers             NaN
# 1         3016       1991  AR0290100            Hope             NaN
# 2           43       1991  AR0350100      Pine Bluff             NaN
# 3           44       1991  AR0350100      Pine Bluff             NaN
# 4         3017       1991  AR0350100      Pine Bluff             NaN
#
#   AGENCY_TYPE_NAME STATE_ABBR STATE_NAME       DIVISION_NAME REGION_NAME  ...  \
# 0             City         AR   Arkansas  West South Central       South  ...
# 1             City         AR   Arkansas  West South Central       South  ...
# 2             City         AR   Arkansas  West South Central       South  ...
# 3             City         AR   Arkansas  West South Central       South  ...
# 4             City         AR   Arkansas  West South Central       South  ...
#
#                OFFENDER_RACE OFFENDER_ETHNICITY VICTIM_COUNT  \
# 0                      White                NaN            1
# 1  Black or African American                NaN            1
# 2  Black or African American                NaN            1
# 3  Black or African American                NaN            2
# 4  Black or African American                NaN            1
#
#                                         OFFENSE_NAME  \
# 0                                       Intimidation
# 1                                     Simple Assault
# 2                                 Aggravated Assault
# 3  Aggravated Assault;Destruction/Damage/Vandalis...
# 4                                 Aggravated Assault
#
#    TOTAL_INDIVIDUAL_VICTIMS                       LOCATION_NAME  \
# 0                       1.0  Highway/Road/Alley/Street/Sidewalk
# 1                       1.0  Highway/Road/Alley/Street/Sidewalk
# 2                       1.0                      Residence/Home
# 3                       1.0  Highway/Road/Alley/Street/Sidewalk
# 4                       1.0                 Service/Gas Station
#
#                         BIAS_DESC  VICTIM_TYPES MULTIPLE_OFFENSE MULTIPLE_BIAS
# 0  Anti-Black or African American    Individual                S             S
# 1                      Anti-White    Individual                S             S
# 2  Anti-Black or African American    Individual                S             S
# 3                      Anti-White    Individual                M             S
# 4                      Anti-White    Individual                S             S
#
# [5 rows x 28 columns]

# %%
# filter by year 2014-2018 (5Years)

filtered_hate_crime_df = hate_crime_df[(hate_crime_df["DATA_YEAR"] >= 2014) & (hate_crime_df["DATA_YEAR"] <= 2018)]
filtered_hate_crime_df.head()
# Out:
#         INCIDENT_ID  DATA_YEAR        ORI PUB_AGENCY_NAME PUB_AGENCY_UNIT  \
# 169146       174732       2014  AK0010100       Anchorage             NaN
# 169147       174733       2014  AK0010100       Anchorage             NaN
# 169148       174734       2014  AK0010100       Anchorage             NaN
# 169149       174735       2014  AK0010100       Anchorage             NaN
# 169150       174736       2014  AK0010100       Anchorage             NaN
#
#        AGENCY_TYPE_NAME STATE_ABBR STATE_NAME DIVISION_NAME REGION_NAME  ...  \
# 169146             City         AK     Alaska       Pacific        West  ...
# 169147             City         AK     Alaska       Pacific        West  ...
# 169148             City         AK     Alaska       Pacific        West  ...
# 169149             City         AK     Alaska       Pacific        West  ...
# 169150             City         AK     Alaska       Pacific        West  ...
#
#                     OFFENDER_RACE OFFENDER_ETHNICITY VICTIM_COUNT  \
# 169146                    Unknown            Unknown            2
# 169147                      White            Unknown            1
# 169148                      White            Unknown            1
# 169149  Black or African American            Unknown            2
# 169150                      White            Unknown            1
#
#                                     OFFENSE_NAME  TOTAL_INDIVIDUAL_VICTIMS  \
# 169146  Destruction/Damage/Vandalism of Property                       2.0
# 169147                        Aggravated Assault                       1.0
# 169148                            Simple Assault                       1.0
# 169149                                   Robbery                       2.0
# 169150                            Simple Assault                       1.0
#
#                    LOCATION_NAME                              BIAS_DESC  \
# 169146            Residence/Home                        Anti-Gay (Male)
# 169147   Parking/Drop Lot/Garage  Anti-American Indian or Alaska Native
# 169148  Shelter-Mission/Homeless         Anti-Black or African American
# 169149   Parking/Drop Lot/Garage  Anti-American Indian or Alaska Native
# 169150   Parking/Drop Lot/Garage  Anti-American Indian or Alaska Native
#
#         VICTIM_TYPES MULTIPLE_OFFENSE MULTIPLE_BIAS
# 169146    Individual                S             S
# 169147    Individual                S             S
# 169148    Individual                S             S
# 169149    Individual                S             S
# 169150    Individual                S             S
#
# [5 rows x 28 columns]

# %%
# Sort the states by their STATE_NAME
state_df = filtered_hate_crime_df.sort_values("STATE_NAME")
state_df
# Out:
#         INCIDENT_ID  DATA_YEAR        ORI                PUB_AGENCY_NAME  \
# 180637       180590       2016  AL0010200                     Birmingham
# 186907       191575       2017  AL0110800  Jacksonville State University
# 186906       598847       2017  AL0011200                         Hoover
# 186905       598829       2017  AL0011200                         Hoover
# 186904       546958       2017  AL0011200                         Hoover
# ...             ...        ...        ...                            ...
# 194207       194469       2017  WY0010200          University of Wyoming
# 194206       193399       2017  WY0010100                        Laramie
# 180623       180578       2015  WY0030100                       Gillette
# 186891       186844       2016  WY0030100                       Gillette
# 194205       190213       2017  WY0010100                        Laramie
#
#        PUB_AGENCY_UNIT       AGENCY_TYPE_NAME STATE_ABBR STATE_NAME  \
# 180637             NaN                   City         AL    Alabama
# 186907             NaN  University or College         AL    Alabama
# 186906             NaN                   City         AL    Alabama
# 186905             NaN                   City         AL    Alabama
# 186904             NaN                   City         AL    Alabama
# ...                ...                    ...        ...        ...
# 194207             NaN  University or College         WY    Wyoming
# 194206             NaN                   City         WY    Wyoming
# 180623             NaN                   City         WY    Wyoming
# 186891             NaN                   City         WY    Wyoming
# 194205             NaN                   City         WY    Wyoming
#
#              DIVISION_NAME REGION_NAME  ...              OFFENDER_RACE  \
# 180637  East South Central       South  ...                      White
# 186907  East South Central       South  ...  Black or African American
# 186906  East South Central       South  ...                      White
# 186905  East South Central       South  ...                    Unknown
# 186904  East South Central       South  ...                      White
# ...                    ...         ...  ...                        ...
# 194207            Mountain        West  ...                   Multiple
# 194206            Mountain        West  ...                    Unknown
# 180623            Mountain        West  ...                      White
# 186891            Mountain        West  ...                      White
# 194205            Mountain        West  ...                    Unknown
#
#             OFFENDER_ETHNICITY VICTIM_COUNT  \
# 180637                 Unknown            2
# 186907  Not Hispanic or Latino            1
# 186906                 Unknown            1
# 186905                 Unknown            1
# 186904                 Unknown            1
# ...                        ...          ...
# 194207                Multiple           20
# 194206                 Unknown            1
# 180623                     NaN            1
# 186891                 Unknown            1
# 194205                 Unknown            1
#
#                                     OFFENSE_NAME  TOTAL_INDIVIDUAL_VICTIMS  \
# 180637                              Intimidation                       2.0
# 186907                              Intimidation                       1.0
# 186906                              Intimidation                       1.0
# 186905  Destruction/Damage/Vandalism of Property                       1.0
# 186904                            Simple Assault                       1.0
# ...                                          ...                       ...
# 194207                              Intimidation                      20.0
# 194206  Destruction/Damage/Vandalism of Property                       NaN
# 180623                            Simple Assault                       1.0
# 186891                            Simple Assault                       1.0
# 194205  Destruction/Damage/Vandalism of Property                       NaN
#
#                              LOCATION_NAME  \
# 180637             Parking/Drop Lot/Garage
# 186907           School-College/University
# 186906                      Residence/Home
# 186905                      Residence/Home
# 186904  Highway/Road/Alley/Street/Sidewalk
# ...                                    ...
# 194207  Highway/Road/Alley/Street/Sidewalk
# 194206                          Restaurant
# 180623            Shelter-Mission/Homeless
# 186891                      Residence/Home
# 194205      Church/Synagogue/Temple/Mosque
#
#                                                 BIAS_DESC  \
# 180637                     Anti-Black or African American
# 186907                                         Anti-White
# 186906                     Anti-Black or African American
# 186905                     Anti-Black or African American
# 186904                     Anti-Black or African American
# ...                                                   ...
# 194207              Anti-American Indian or Alaska Native
# 194206  Anti-Lesbian, Gay, Bisexual, or Transgender (M...
# 180623                     Anti-Black or African American
# 186891                     Anti-Black or African American
# 194205                                    Anti-Protestant
#
#                   VICTIM_TYPES MULTIPLE_OFFENSE MULTIPLE_BIAS
# 180637              Individual                S             S
# 186907              Individual                S             S
# 186906              Individual                S             S
# 186905              Individual                S             S
# 186904              Individual                S             S
# ...                        ...              ...           ...
# 194207              Individual                S             S
# 194206                Business                S             S
# 180623              Individual                S             S
# 186891              Individual                S             S
# 194205  Religious Organization                S             S
#
# [32257 rows x 28 columns]

# %%
# Interesting Columns of Info for Presentation
columns_df = state_df[['INCIDENT_DATE', 'DATA_YEAR', 'PUB_AGENCY_NAME', 'STATE_NAME', 'POPULATION_GROUP_DESC', 'OFFENSE_NAME', 'BIAS_DESC']]
columns_df.head()
# Out:
#        INCIDENT_DATE  DATA_YEAR                PUB_AGENCY_NAME STATE_NAME  \
# 180637     25-MAR-16       2016                     Birmingham    Alabama
# 186907     23-SEP-17       2017  Jacksonville State University    Alabama
# 186906     30-AUG-17       2017                         Hoover    Alabama
# 186905     31-JUL-17       2017                         Hoover    Alabama
# 186904     06-JUN-17       2017                         Hoover    Alabama
#
#                    POPULATION_GROUP_DESC  \
# 180637  Cities from 100,000 thru 249,999
# 186907                Cities under 2,500
# 186906    Cities from 50,000 thru 99,999
# 186905    Cities from 50,000 thru 99,999
# 186904    Cities from 50,000 thru 99,999
#
#                                     OFFENSE_NAME  \
# 180637                              Intimidation
# 186907                              Intimidation
# 186906                              Intimidation
# 186905  Destruction/Damage/Vandalism of Property
# 186904                            Simple Assault
#
#                              BIAS_DESC
# 180637  Anti-Black or African American
# 186907                      Anti-White
# 186906  Anti-Black or African American
# 186905  Anti-Black or African American
# 186904  Anti-Black or African American

# %%
# Making sure there is data in every column. If there were NA's, drop them.
columns_df.count()
# Out:
# INCIDENT_DATE            32257
# DATA_YEAR                32257
# PUB_AGENCY_NAME          32257
# STATE_NAME               32257
# POPULATION_GROUP_DESC    32257
# OFFENSE_NAME             32257
# BIAS_DESC                32257
# dtype: int64

# %%
#Determine the amount of States. If there are any to ignore, do so.

len(columns_df["STATE_NAME"].unique())
# Out:
# 53

# %%
# Hate Crime counts for each state for the years of 
state_count_df = columns_df["STATE_NAME"].value_counts()
state_count_df
# Out:
# California              4696
# New York                2719
# Ohio                    2060
# New Jersey              2021
# Washington              2006
# Massachusetts           1975
# Michigan                1924
# Arizona                 1191
# Kentucky                1190
# Texas                   1119
# Tennessee                872
# Virginia                 771
# North Carolina           756
# District of Columbia     657
# Minnesota                596
# Oregon                   546
# Florida                  535
# Connecticut              518
# Illinois                 503
# Colorado                 478
# Missouri                 443
# Indiana                  391
# Kansas                   340
# Pennsylvania             321
# South Carolina           291
# Utah                     264
# Maryland                 249
# West Virginia            245
# Wisconsin                237
# Georgia                  188
# Nebraska                 175
# Louisiana                164
# Oklahoma                 163
# Nevada                   161
# Maine                    159
# Idaho                    154
# Montana                  133
# Vermont                  124
# North Dakota             115
# New Mexico               111
# Delaware                  89
# South Dakota              87
# New Hampshire             84
# Mississippi               81
# Arkansas                  76
# Iowa                      59
# Rhode Island              59
# Alabama                   49
# Hawaii                    44
# Alaska                    36
# Federal                   22
# Wyoming                    9
# Guam                       1
# Name: STATE_NAME, dtype: int64

# %%
len(columns_df["PUB_AGENCY_NAME"].unique())
# Out:
# 3401

# %%
###### This is where I need to update the cities by the population to get refined data for populations over 250,000.

cities_count_df = columns_df.loc[(columns_df['POPULATION_GROUP_DESC'] == "Cities from 250,000 thru 499,999") | (columns_df['POPULATION_GROUP_DESC'] == "Cities from 500,000 thru 999,999") | (columns_df['POPULATION_GROUP_DESC'] == "Cities 1,000,000 or over"), ['INCIDENT_DATE', 'DATA_YEAR', 'PUB_AGENCY_NAME', 'STATE_NAME', 'POPULATION_GROUP_DESC', 'OFFENSE_NAME', 'BIAS_DESC'] ]
cities_count_df
# Out:
#        INCIDENT_DATE  DATA_YEAR PUB_AGENCY_NAME STATE_NAME  \
# 169146     06-DEC-14       2014       Anchorage     Alaska
# 174747     31-JUL-15       2015       Anchorage     Alaska
# 174748     11-JUN-15       2015       Anchorage     Alaska
# 174749     03-AUG-15       2015       Anchorage     Alaska
# 180624     12-FEB-16       2016       Anchorage     Alaska
# ...              ...        ...             ...        ...
# 174709     24-JUN-14       2014       Milwaukee  Wisconsin
# 174708     23-MAY-14       2014       Milwaukee  Wisconsin
# 174707     21-APR-14       2014       Milwaukee  Wisconsin
# 174706     17-FEB-14       2014       Milwaukee  Wisconsin
# 174705     09-FEB-14       2014       Milwaukee  Wisconsin
#
#                    POPULATION_GROUP_DESC  \
# 169146  Cities from 250,000 thru 499,999
# 174747  Cities from 250,000 thru 499,999
# 174748  Cities from 250,000 thru 499,999
# 174749  Cities from 250,000 thru 499,999
# 180624  Cities from 250,000 thru 499,999
# ...                                  ...
# 174709  Cities from 500,000 thru 999,999
# 174708  Cities from 500,000 thru 999,999
# 174707  Cities from 500,000 thru 999,999
# 174706  Cities from 500,000 thru 999,999
# 174705  Cities from 500,000 thru 999,999
#
#                                     OFFENSE_NAME  \
# 169146  Destruction/Damage/Vandalism of Property
# 174747                              Intimidation
# 174748                                     Arson
# 174749                        Aggravated Assault
# 180624                            Simple Assault
# ...                                          ...
# 174709                                   Robbery
# 174708                              Intimidation
# 174707                              Intimidation
# 174706                              Intimidation
# 174705                              Intimidation
#
#                                                 BIAS_DESC
# 169146                                    Anti-Gay (Male)
# 174747                     Anti-Black or African American
# 174748  Anti-Lesbian, Gay, Bisexual, or Transgender (M...
# 174749                     Anti-Black or African American
# 180624                     Anti-Black or African American
# ...                                                   ...
# 174709                                         Anti-White
# 174708                                        Anti-Jewish
# 174707                 Anti-Other Race/Ethnicity/Ancestry
# 174706                                    Anti-Gay (Male)
# 174705                                      Anti-Catholic
#
# [10955 rows x 7 columns]

# %%
# Counts of all cities within the 250,000 pop criteria
pop_cities_df = cities_count_df[('PUB_AGENCY_NAME')].value_counts()
pop_cities_df
# Out:
# New York       1644
# Los Angeles    1116
# Phoenix         914
# Seattle         840
# Boston          640
#                ...
# Chandler          6
# Anaheim           4
# Tulsa             2
# Reno              2
# Gilbert           1
# Name: PUB_AGENCY_NAME, Length: 85, dtype: int64

# %%
# Showing the top 20 states
# Display the data with a clean layout
most_hate_crime_df = pd.DataFrame(pop_cities_df)
most_hate_crime_df.head(20)
# Out:
#                        PUB_AGENCY_NAME
# New York                          1644
# Los Angeles                       1116
# Phoenix                            914
# Seattle                            840
# Boston                             640
# Columbus                           605
# Washington                         599
# Chicago                            242
# Cincinnati                         202
# San Francisco                      197
# Kansas City                        197
# San Diego                          189
# Detroit                            154
# Minneapolis                        154
# Lexington                          151
# Indianapolis                       145
# Philadelphia                       140
# Charlotte-Mecklenburg              136
# San Jose                           118
# Lincoln                            104

# %%
# Showing the bottom 20 states
# Display the data with a clean layout 
least_hate_crime_df = pd.DataFrame(pop_cities_df)
least_hate_crime_df.tail(20)
# Out:
#                 PUB_AGENCY_NAME
# Jersey City                  16
# Oklahoma City                16
# Chula Vista                  13
# Jacksonville                 12
# Irvine                       11
# Baltimore                    11
# Fort Wayne                   11
# Miami                        10
# Lubbock                       9
# El Paso                       9
# Scottsdale                    9
# Newark                        8
# Plano                         8
# Corpus Christi                8
# Tampa                         7
# Chandler                      6
# Anaheim                       4
# Tulsa                         2
# Reno                          2
# Gilbert                       1
