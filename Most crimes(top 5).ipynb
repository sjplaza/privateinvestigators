# %%
import pandas as pd
import numpy as np
import os
import csv
import matplotlib.pyplot as plt

# %%
#store file path
hate_crime = "hate_crime/hate_crime.csv"

#import data into panda DF
hate_crime_df = pd.read_csv(hate_crime, low_memory=False)
hate_crime_df
# Out:
#         INCIDENT_ID  DATA_YEAR        ORI PUB_AGENCY_NAME PUB_AGENCY_UNIT  \
# 0              3015       1991  AR0040200          Rogers             NaN
# 1              3016       1991  AR0290100            Hope             NaN
# 2                43       1991  AR0350100      Pine Bluff             NaN
# 3                44       1991  AR0350100      Pine Bluff             NaN
# 4              3017       1991  AR0350100      Pine Bluff             NaN
# ...             ...        ...        ...             ...             ...
# 201398       466130       2018  WV0540100     Parkersburg             NaN
# 201399       466159       2018  WV0540100     Parkersburg             NaN
# 201400       508677       2018  WV0540200          Vienna             NaN
# 201401       463503       2018  WVWSP2400   State Police:         Madison
# 201402       544359       2018  WVWSP3300   State Police:     Parkersburg
#
#        AGENCY_TYPE_NAME STATE_ABBR     STATE_NAME       DIVISION_NAME  \
# ...

# %%
#put offense name in seperate column
hate_crime_df[["OFFENSE_NAME"]]
# Out:
#                                              OFFENSE_NAME
# 0                                            Intimidation
# 1                                          Simple Assault
# 2                    Aggravated Assault;All Other Larceny
# 3       Aggravated Assault;Destruction/Damage/Vandalis...
# 4                    Aggravated Assault;All Other Larceny
# ...                                                   ...
# 201398                       Burglary/Breaking & Entering
# 201399                                     Simple Assault
# 201400                                       Intimidation
# 201401                                       Intimidation
# 201402  Burglary/Breaking & Entering;Destruction/Damag...
#
# [201403 rows x 1 columns]

# %%
#finding name of the offense name

hate_crime_df["OFFENSE_NAME"].unique()
# Out:
# array(['Intimidation', 'Simple Assault',
#        'Aggravated Assault;All Other Larceny',
#        'Aggravated Assault;Destruction/Damage/Vandalism of Property',
#        'Robbery',
#        'Aggravated Assault;Murder and Nonnegligent Manslaughter',
#        'Destruction/Damage/Vandalism of Property',
#        'Destruction/Damage/Vandalism of Property;Intimidation',
#        'Aggravated Assault;Intimidation',
#        'Aggravated Assault;Not Specified', 'Intimidation;Simple Assault',
#        'Arson',
#        'Destruction/Damage/Vandalism of Property;Intimidation;Simple Assault',
#        'Burglary/Breaking & Entering;Destruction/Damage/Vandalism of Property;Not Specified',
#        'Murder and Nonnegligent Manslaughter',
#        'Intimidation;Not Specified',
#        'Destruction/Damage/Vandalism of Property;Not Specified',
#        'Burglary/Breaking & Entering',
#        'Destruction/Damage/Vandalism of Property;Simple Assault',
# ...

# %%
#finding how many people commited aggravated assault

hate_crime_df[""]

# %%
#number of offenses 
#also need number off offenses for last 5 years????

offense_name_count = len(hate_crime_df["OFFENSE_NAME"].unique())
offense_name_count
# Out:
# 332

# %%
#combine similiar offenses together
hate_crime_df = hate_crime_df.replace(
{"Aggravated Assault": "Aggravated Assault;All Other Larceny"})
hate_crime_df
# Out:
#         INCIDENT_ID  DATA_YEAR        ORI PUB_AGENCY_NAME PUB_AGENCY_UNIT  \
# 0              3015       1991  AR0040200          Rogers             NaN
# 1              3016       1991  AR0290100            Hope             NaN
# 2                43       1991  AR0350100      Pine Bluff             NaN
# 3                44       1991  AR0350100      Pine Bluff             NaN
# 4              3017       1991  AR0350100      Pine Bluff             NaN
# ...             ...        ...        ...             ...             ...
# 201398       466130       2018  WV0540100     Parkersburg             NaN
# 201399       466159       2018  WV0540100     Parkersburg             NaN
# 201400       508677       2018  WV0540200          Vienna             NaN
# 201401       463503       2018  WVWSP2400   State Police:         Madison
# 201402       544359       2018  WVWSP3300   State Police:     Parkersburg
#
#        AGENCY_TYPE_NAME STATE_ABBR     STATE_NAME       DIVISION_NAME  \
# ...

# %%
#get numbers of offenses

hate_crime_df["OFFENSE_NAME"].value_counts()
# Out:
# Destruction/Damage/Vandalism of Property                                                     62147
# Intimidation                                                                                 58751
# Simple Assault                                                                               38042
# Aggravated Assault;All Other Larceny                                                         21013
# Robbery                                                                                       3454
#                                                                                              ...
# Destruction/Damage/Vandalism of Property;Intimidation;Robbery;Simple Assault                     1
# Aggravated Assault;Intimidation;Kidnapping/Abduction;Weapon Law Violations                       1
# Burglary/Breaking & Entering;Drug/Narcotic Violations                                            1
# ...

# %%
#sort offense names in alphabetical order based on "offense name" column
offense_name_df = offense_name_df.sort_values("OFFENSE_NAME")
offense_name_df.head()
# Out:
#               OFFENSE_NAME
# 58775   Aggravated Assault
# 155854  Aggravated Assault
# 97012   Aggravated Assault
# 24264   Aggravated Assault
# 24285   Aggravated Assault
