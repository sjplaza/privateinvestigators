# %%
import pandas as pd
import numpy as np
import os
import csv
import matplotlib.pyplot as plt

# %%
#store file path
hate_crime = "hate_crime/hate_crime.csv"

#import data into panda DF
hate_crime = pd.read_csv(hate_crime, low_memory=False)
hate_crime
# Out:
#         INCIDENT_ID  DATA_YEAR        ORI PUB_AGENCY_NAME PUB_AGENCY_UNIT  \
# 0              3015       1991  AR0040200          Rogers             NaN
# 1              3016       1991  AR0290100            Hope             NaN
# 2                43       1991  AR0350100      Pine Bluff             NaN
# 3                44       1991  AR0350100      Pine Bluff             NaN
# 4              3017       1991  AR0350100      Pine Bluff             NaN
# ...             ...        ...        ...             ...             ...
# 201398       466130       2018  WV0540100     Parkersburg             NaN
# 201399       466159       2018  WV0540100     Parkersburg             NaN
# 201400       508677       2018  WV0540200          Vienna             NaN
# 201401       463503       2018  WVWSP2400   State Police:         Madison
# 201402       544359       2018  WVWSP3300   State Police:     Parkersburg
#
#        AGENCY_TYPE_NAME STATE_ABBR     STATE_NAME       DIVISION_NAME  \
# ...

# %%
#get offenses name in a column
hate_crime_df = hate_crime_df[["OFFENSE_NAME"]]

# %%
#get numbers of offenses

hate_crime_df["OFFENSE_NAME"].value_counts()
# Out:
# Destruction/Damage/Vandalism of Property                                      62147
# Intimidation                                                                  58751
# Simple Assault                                                                38042
# Aggravated Assault                                                            20999
# Robbery                                                                        3454
#                                                                               ...
# Aggravated Assault;Intimidation;Kidnapping/Abduction;Weapon Law Violations        1
# Robbery;Sexual Assault With An Object                                             1
# Impersonation;Pornography/Obscene Material                                        1
# Pornography/Obscene Material;Rape                                                 1
# Burglary/Breaking & Entering;Rape                                                 1
# Name: OFFENSE_NAME, Length: 333, dtype: int64

# %%
#sort offense names in alphabetical order
hate_crime_df = hate_crime.sort_values("OFFENSE_NAME", ascending=False)
hate_crime_df.head()
# Out:
#         INCIDENT_ID  DATA_YEAR        ORI PUB_AGENCY_NAME PUB_AGENCY_UNIT  \
# 128224       125292       2007  UT0060100       Bountiful             NaN
# 164411       164406       2013  CT0013500        Stamford             NaN
# 173580       173356       2014  OHCOP0000        Columbus             NaN
# 180453       180220       2015  WASPD0000         Seattle             NaN
# 200541       594982       2018  VA0010000        Accomack             NaN
#
#        AGENCY_TYPE_NAME STATE_ABBR   STATE_NAME       DIVISION_NAME  \
# 128224             City         UT         Utah            Mountain
# 164411             City         CT  Connecticut         New England
# 173580             City         OH         Ohio  East North Central
# 180453             City         WA   Washington             Pacific
# 200541           County         VA     Virginia      South Atlantic
#
#        REGION_NAME  ...              OFFENDER_RACE OFFENDER_ETHNICITY  \
# ...
